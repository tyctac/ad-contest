# %%
cd ..
# Out:
# /home/zw/Documents/project/ad-contest

# %%
from utils.often_use import *

# %%
ad, position, train, user, app_cat, test, ua_ac, user_apps = import_origin()
# Out:
# /home/zw/Documents/project/ad-contest/raw_data/pre/

# %%
train = pd.read_csv('note_book_code/middle_file/train_pre_29.csv')

# %%
appcount_of_user = pd.read_csv('note_book_code/middle_file/appcount_of_user.csv')

creative_popu = pd.read_csv('note_book_code/middle_file/creative_popu.csv')

# %%
creative_popu
# Out:
#     Unnamed: 0  appID     0  user_count  popularity
# 0            0     14   191         NaN         NaN
# 1            1     25    10         NaN         NaN
# 2            2     68    15         NaN         NaN
# 3            3     75    11         NaN         NaN
# 4            4     83     6         NaN         NaN
# 5            5     84   103         NaN         NaN
# 6            6     88     4         NaN         NaN
# 7            7    100    64         NaN         NaN
# 8            8    105    25         NaN         NaN
# 9            9    109     8         NaN         NaN
# 10          10    113     3         NaN         NaN
# 11          11    116   142         NaN         NaN
# 12          12    123   713         NaN         NaN
# 13          13    127    57         NaN         NaN
# 14          14    137     3         NaN         NaN
# 15          15    146    43         NaN         NaN
# 16          16    150    34         NaN         NaN
# ...

# %%
creative_popu.columns
# Out:
# Index([u'Unnamed: 0', u'appID', u'0', u'user_count', u'popularity'], dtype='object')

# %%
creative_popu['popularity'].isnull()
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9      True
# 10     True
# 11     True
# 12     True
# 13     True
# 14     True
# 15     True
# 16     True
# 17     True
# 18     True
# 19     True
# 20     True
# 21     True
# 22     True
# 23     True
# 24     True
# 25     True
# 26     True
# 27     True
# 28     True
# 29     True
# 30     True
# 31     True
# 32     True
# 33     True
# 34     True
# 35     True
# 36     True
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49     True
# Name: popularity, dtype: bool

# %%
creative_popu_loss = creative_popu.loc[creative_popu['popularity'].isnull(),:]

# %%
creative_popu2 = creative_popu[['appID','user_count','popularity']]
creative_popu2
# Out:
#     appID  user_count  popularity
# 0      14         NaN         NaN
# 1      25         NaN         NaN
# 2      68         NaN         NaN
# 3      75         NaN         NaN
# 4      83         NaN         NaN
# 5      84         NaN         NaN
# 6      88         NaN         NaN
# 7     100         NaN         NaN
# 8     105         NaN         NaN
# 9     109         NaN         NaN
# 10    113         NaN         NaN
# 11    116         NaN         NaN
# 12    123         NaN         NaN
# 13    127         NaN         NaN
# 14    137         NaN         NaN
# 15    146         NaN         NaN
# 16    150         NaN         NaN
# 17    160         NaN         NaN
# 18    195         NaN         NaN
# 19    198         NaN         NaN
# 20    205         NaN         NaN
# 21    206         NaN         NaN
# 22    218         NaN         NaN
# 23    229         NaN         NaN
# 24    262         NaN         NaN
# 25    271         NaN         NaN
# ...

# %%
ad2 = pd.merge(ad,creative_popu2,how = 'left',on='appID')

# %%
ad2
# Out:
#       creativeID  adID  camgaignID  advertiserID  appID  appPlatform  \
# 0           4079  2318         147            80     14            2
# 1           4565  3593         632             3    465            1
# 2           3170  1593         205            54    389            1
# 3           6566  2390         205            54    389            1
# 4           5187   411         564             3    465            1
# 5           6440  3379         411             3    465            1
# 6           2367   364         139            10    434            1
# 7           4686   834         107            80     14            2
# 8           2553  2519          60             3    465            1
# 9           5832   100          73            54    389            1
# 10          2392  2249         205            54    389            1
# 11          5942  3598         693            26    123            2
# 12          5949  3084         566            80     14            2
# ...

# %%
train = pd.merge(train,ad2,how = 'left',on='creativeID')

# %%
train
# Out:
#          Unnamed: 0  label  clickTime  conversionTime  creativeID   userID  \
# 0                 0      0     170000             NaN        3089  2798058
# 1                 1      0     170000             NaN        1259   463234
# 2                 2      0     170000             NaN        4465  1857485
# 3                 3      0     170000             NaN        1004  2038823
# 4                 4      0     170000             NaN        1887  2015141
# 5                 5      0     170000             NaN        3293  1177829
# 6                 6      0     170000             NaN        4793  1257450
# 7                 7      0     170000             NaN        1456   764204
# 8                 8      0     170000             NaN        4465  1438585
# 9                 9      0     170000             NaN         985  1750317
# 10               10      0     170000             NaN        3465  2079582
# ...

# %%
appcount_of_user = appcount_of_user[['userID','appcount','love_app']]

# %%
appcount_of_user
# Out:
#           userID  appcount  love_app
# 0           2838       505         4
# 1        1528113       480         4
# 2        1833356       465         4
# 3         615270       445         4
# 4        1849498       445         4
# 5        2121040       433         4
# 6         281637       428         4
# 7         403929       426         4
# 8        1679435       426         4
# 9        2379067       414         4
# 10       1914385       412         4
# 11        845201       411         4
# 12       1461702       406         4
# 13        373403       405         4
# 14       2648363       405         4
# 15       1700502       401         4
# 16       1906419       400         4
# 17        562051       395         4
# 18        291838       392         4
# 19        215857       390         4
# 20       1686079       389         4
# 21        305463       389         4
# 22        604933       386         4
# 23       2169166       386         4
# ...

# %%
user = pd.merge(user,appcount_of_user,how='left',on='userID')

# %%
user
# Out:
#           userID  age  gender  education  marriageStatus  haveBaby  hometown  \
# 0              1   42       1          0               2         0       512
# 1              2   18       1          5               1         0      1403
# 2              3    0       2          4               0         0         0
# 3              4   21       2          5               3         0       607
# 4              5   22       2          0               0         0         0
# 5              6   20       2          0               0         0       301
# 6              7   17       1          5               0         0       313
# 7              8   21       1          2               3         1      1607
# 8              9   38       2          2               2         0      2203
# 9             10   13       2          0               0         0         0
# 10            11   17       2          3               2         1      2405
# ...

# %%
train
# Out:
#          Unnamed: 0  label  clickTime  conversionTime  creativeID   userID  \
# 0                 0      0     170000             NaN        3089  2798058
# 1                 1      0     170000             NaN        1259   463234
# 2                 2      0     170000             NaN        4465  1857485
# 3                 3      0     170000             NaN        1004  2038823
# 4                 4      0     170000             NaN        1887  2015141
# 5                 5      0     170000             NaN        3293  1177829
# 6                 6      0     170000             NaN        4793  1257450
# 7                 7      0     170000             NaN        1456   764204
# 8                 8      0     170000             NaN        4465  1438585
# 9                 9      0     170000             NaN         985  1750317
# 10               10      0     170000             NaN        3465  2079582
# ...

# %%
train = pd.merge(train,user,how='left',on='userID')

# %%
train
# Out:
#          Unnamed: 0  label  clickTime  conversionTime  creativeID   userID  \
# 0                 0      0     170000             NaN        3089  2798058
# 1                 1      0     170000             NaN        1259   463234
# 2                 2      0     170000             NaN        4465  1857485
# 3                 3      0     170000             NaN        1004  2038823
# 4                 4      0     170000             NaN        1887  2015141
# 5                 5      0     170000             NaN        3293  1177829
# 6                 6      0     170000             NaN        4793  1257450
# 7                 7      0     170000             NaN        1456   764204
# 8                 8      0     170000             NaN        4465  1438585
# 9                 9      0     170000             NaN         985  1750317
# 10               10      0     170000             NaN        3465  2079582
# ...

# %%
train.to_csv('note_book_code/middle_file/train_full.csv')

# %%
test = pd.merge(test,ad2,how='left',on='creativeID')

# %%
test = pd.merge(test,user,how='left',on='userID')

# %%
test
# Out:
#         instanceID  label  clickTime  creativeID   userID  positionID  \
# 0                1     -1     310000        3745  1164848        3451
# 1                2     -1     310000        2284  2127247        1613
# 2                3     -1     310000        1456  2769125        5510
# 3                4     -1     310000        4565     9762        4113
# 4                5     -1     310000          49  2513636        3615
# 5                6     -1     310000        3824   488035        3821
# 6                7     -1     310000         863   225561        4188
# 7                8     -1     310000        4469  1144620        4113
# 8                9     -1     310000        3745  1113275        3347
# 9               10     -1     310000        4565  1361729        2426
# 10              11     -1     310000        4250  1749379        4292
# 11              12     -1     310000        1456   840178        6086
# ...

# %%
test.to_csv('note_book_code/middle_file/test_full.csv')

# %%
train_half = train.loc[train['love_app'].isnull() == True,:]

# %%
train1 = train_half.loc[train_half['popularity'].isnull() == True,:]

# %%
train1.to_csv('note_book_code/middle_file/train1.csv')

# %%
train1 = train_half.loc[train_half['popularity'].isnull() == False,:]

# %%
train1.to_csv('note_book_code/middle_file/train2.csv')

# %%
train_half = train.loc[train['love_app'].isnull() == False,:]

# %%
train1 = train_half.loc[train_half['popularity'].isnull() == True,:]

# %%
train1.to_csv('note_book_code/middle_file/train3.csv')

# %%
train1 = train_half.loc[train_half['popularity'].isnull() == False,:]

# %%
train1.to_csv('note_book_code/middle_file/train4.csv')

# %%
test
# Out:
#         instanceID  label  clickTime  creativeID   userID  positionID  \
# 0                1     -1     310000        3745  1164848        3451
# 1                2     -1     310000        2284  2127247        1613
# 2                3     -1     310000        1456  2769125        5510
# 3                4     -1     310000        4565     9762        4113
# 4                5     -1     310000          49  2513636        3615
# 5                6     -1     310000        3824   488035        3821
# 6                7     -1     310000         863   225561        4188
# 7                8     -1     310000        4469  1144620        4113
# 8                9     -1     310000        3745  1113275        3347
# 9               10     -1     310000        4565  1361729        2426
# 10              11     -1     310000        4250  1749379        4292
# 11              12     -1     310000        1456   840178        6086
# ...

# %%
test_half = test.loc[test['love_app'].isnull() == True,:]

# %%
test1 = test_half.loc[test_half['popularity'].isnull() == True, :]

# %%
test1.to_csv('note_book_code/middle_file/test1.csv')

# %%
test1 = test_half.loc[test_half['popularity'].isnull() == False, :]

# %%
test1.to_csv('note_book_code/middle_file/test2.csv')

# %%
test_half = test.loc[test['love_app'].isnull() == False,:]

# %%
test1 = test_half.loc[test_half['popularity'].isnull() == True, :]

# %%
test1.to_csv('note_book_code/middle_file/test3.csv')

# %%
test1 = test_half.loc[test_half['popularity'].isnull() == False, :]

# %%
test1.to_csv('note_book_code/middle_file/test4.csv')
